# %%
#Import Stuff 
import os
import cv2
import math
import numpy as np

# %% [markdown]
# # Extract Data from Amira Files

# %%
# Open two empty dictionaries for later use
files = {}
landmarks = {}

for filename in os.listdir():
    if os.path.isfile(filename) and filename.endswith(".landmarkAscii") and not filename in files: 
#os.path.isfile() method in Python is used to check whether the specified path is an existing regular file or not.
#the if condition checks for a regular file and if ends with particular extension and also checks if the particular file is already in the dictionary
        with open(filename, "r") as file:
            #opens the particular file in read mode
            files[filename] = file.readlines()
            #file gets added to dictionary 'files'
            # reads all the files into a dictionary
            #readlines() reads line by line as a list

# %%
#prints all the files with given extension in the system
for filename, text in files.items(): 
    print(filename)# prints the list of files with the given extension
    #print(text)# prints the entire contents of the text file
# Out:
# S025_2_Landmarks.landmarkAscii

# %% [markdown]
# ## Extracting Coordinates

# %%
# create a set of lists for coordinates
x_coordinates = [] #x-coordinate
y_coordinates = [] #y-coordinate   
coordinates = [] #x,y-coordinate put together
linecount = 0 #utility variable

#extraction of coordinates
for filename, text in files.items():
    #files is the dict; filename is teh keyword and text is teh value
    # first for loop to enter set of files
    for texts in text:
        # second for loop to enter inside inside the file and access its contents
        if texts.startswith('@1'):
            #looks for line that startswith @1 from the coordinates are listed 
             linecount = 1
             name = filename
             #print(texts)
             #print(filename)
             continue
        if linecount == 1 and texts.isspace() == False and filename==name: 
            #looks for the if @1 has been encountered and counts till an empty space
            #print(texts)
             x = list(map(float,texts.split()))[0]#convert the values into float
             y = list(map(float,texts.split()))[1]
             x_coordinates.append(x)
             y_coordinates.append(y)
             
#coordinates.extend(list(zip(x_coordinates,y_coordinates)))
#print(coordinates)
#print(len(coordinates))

# %%
#fixing the resolution

x_coordinates = [ x/.868 for x in x_coordinates] # division to get the resolution right
y_coordinates = [ y/.868 for y in y_coordinates]

x_coordinates = [int(i) for i in x_coordinates]
y_coordinates = [int(i) for i in y_coordinates]

x = x_coordinates
y = y_coordinates

# %%
# The final Coordinates are obtained as a tuple
coordinates = list(zip(x_coordinates, y_coordinates))
#print(coordinates)
print(len(coordinates))
# Out:
# 727

# %% [markdown]
# # Access the coordinates and crop the image around the coordinates

# %%
# Now that we have the coordinates, need to go to those coordinates and crop it out around it

#Read the image
source_path = '/Users/keshavaprasad/Desktop/image/MG23_bs_S0100_00/MG23_bs_S010_00.tif'
image=cv2.imread(source_path)
#h = image.shape[0]
#w = image.shape[1]
#print("Height, width = ",image.shape)
#print("Total pixels: ", image.size)
#print("h*w:", h*w)
#Open a empty list of mini images
mini_image = []

def image_crop():
    for i in coordinates:
        #print("stride = 0")
        #print("i[1]:",i[1],"i[0]:",i[0])
        im1 = image[i[1]-25:i[1]+25, i[0]-25:i[0]+25]
        mini_image.append(im1)
        
image_crop()            
#print(len(mini_image))
for k in range(len(mini_image)):
    pass
    #print("K:",k)
    #cv2.imwrite(str(k)+ ".tif", mini_image[k])

# %%
#Read the image
source_path = '/Users/keshavaprasad/Desktop/image/MG23_bs_S0100_00/MG23_bs_S010_00.tif'
image=cv2.imread(source_path)
mini_image = []

def crop():
    print('No shift crop')
    for w,h in coordinates:
        #w,h = i
        #print("Null Crop:")
        #print("Location:"+"h:",h,"w:",w)
        #Stride_Null
        y1 = h-25
        y2 = h+25
        x1 = w-25
        x2 = w+25
        #print("The square:"+"y1:",y1,"x1:",x1,"y2:",y2,"x2:",x2)
        im1 = image[y1:y2, x1:x2]
        mini_image.append(im1)
       
# Lets Stride away!

def horizontal_shift_crop():
    print('horizontal_shift_crop')

    #Right Shift
    for w,h in coordinates:
        #shift1
        shift1 = 20
        w = w + shift1
        #h = h + shift1
        #print("First Crop:")
        #print("Location:"+"h:",h,"w:",w)
        y1 = h-25
        y2 = h+25
        x1 = w-25
        x2 = w+25
        #print("The square:"+"y1:",y1,"x1:",x1,"y2:",y2,"x2:",x2)
        im1 = image[y1:y2, x1:x2]
        mini_image.append(im1)
        
        #shift2
        shift2 = 20
        w = w + shift2
        #h = h + shift2
        #print("Second Crop:")
        #print("Location:"+"h:",h,"w:",w)
        y1 = h-25
        y2 = h+25
        x1 = w-25
        x2 = w+25
        #print("The square:"+"y1:",y1,"x1:",x1,"y2:",y2,"x2:",x2)
        im1 = image[y1:y2, x1:x2]
        mini_image.append(im1)

       
    #Left Shift
    for w,h in coordinates:
        #shift1
        shift1 = 20
        w = w - shift1
        #h = h + shift1
        #print("First Crop:")
        #print("Location:"+"h:",h,"w:",w)
        y1 = h-25
        y2 = h+25
        x1 = w-25
        x2 = w+25
        #print("The square:"+"y1:",y1,"x1:",x1,"y2:",y2,"x2:",x2)
        im1 = image[y1:y2, x1:x2]
        mini_image.append(im1)
        
        #shift2
        shift2 = 20
        w = w + shift2
        #h = h + shift2
        #print("Second Crop:")
        #print("Location:"+"h:",h,"w:",w)
        y1 = h-25
        y2 = h+25
        x1 = w-25
        x2 = w+25
        #print("The square:"+"y1:",y1,"x1:",x1,"y2:",y2,"x2:",x2)
        im1 = image[y1:y2, x1:x2]
        mini_image.append(im1)

def vertical_shift_crop():
    print('vertical_shift_crop')

    #Top Shift
    for w,h in coordinates:
        #shift1
        shift1 = 20
        #w = w + shift1
        h = h + shift1
        #print("First Crop:")
        #print("Location:"+"h:",h,"w:",w)
        y1 = h-25
        y2 = h+25
        x1 = w-25
        x2 = w+25
        #print("The square:"+"y1:",y1,"x1:",x1,"y2:",y2,"x2:",x2)
        im1 = image[y1:y2, x1:x2]
        mini_image.append(im1)
        
        #shift2
        shift2 = 20
        #w = w + shift2
        h = h + shift2
        #print("Second Crop:")
        #print("Location:"+"h:",h,"w:",w)
        y1 = h-25
        y2 = h+25
        x1 = w-25
        x2 = w+25
        #print("The square:"+"y1:",y1,"x1:",x1,"y2:",y2,"x2:",x2)
        im1 = image[y1:y2, x1:x2]
        mini_image.append(im1)

       
    #Bottom Shift
    for w,h in coordinates:
        #shift1
        shift = 20
        w = w - shift
        #h = h + shift1
        #print("First Crop:")
        #print("Location:"+"h:",h,"w:",w)
        y1 = h-25
        y2 = h+25
        x1 = w-25
        x2 = w+25
        #print("The square:"+"y1:",y1,"x1:",x1,"y2:",y2,"x2:",x2)
        im1 = image[y1:y2, x1:x2]
        mini_image.append(im1)
        
        #shift2
        shift2 = 20
        w = w + shift2
        #h = h + shift2
        #print("Second Crop:")
        #print("Location:"+"h:",h,"w:",w)
        y1 = h-25
        y2 = h+25
        x1 = w-25
        x2 = w+25
        #print("The square:"+"y1:",y1,"x1:",x1,"y2:",y2,"x2:",x2)
        im1 = image[y1:y2, x1:x2]
        mini_image.append(im1)
        
crop()
horizontal_shift_crop()
vertical_shift_crop()
#Save the image
for k in range(len(mini_image)):
    #pass
    #print("K:",k)
    Dest_Path = '/Users/keshavaprasad/Desktop/image/MG23_bs_S0100_00/MG23_bs_S0100_00_stridingimages_L1files/'
    #Dest_Path = '/Users/keshavaprasad/Desktop/image_20/image20_stridingimages_L2files/'
    cv2.imwrite(os.path.join(Dest_Path,str(k)+".tif"), mini_image[k])
# Out:
# horizontal_shift_crop
# vertical_shift_crop

# %%
#Second Approach
# Setting the points for rectangle of cropped image 
'''
mini_image = []

def crop():
    shift = 10
    for i in coordinates:
        #stride_number = 0
        #print("stride_number:", stride_number)
        #print(i)
        #if stride_number == 0:
        im1 = image[i[1]-25:i[1]+25, i[0]-25:i[0]+25 ] #stride 0
        mini_image.append(im1)
            #stride_number += 1
      
        def stride_right():
            print("stride_number:", stride_number)
            if stride_number == 1:
                im1 = image[i[1]-25+ stride_number*shift:i[1]+25+ stride_number*shift, i[0]-25+ stride_number*shift:i[0]+25+ stride_number*shift] #stride_right 1
                mini_image.append(im1)
                stride_number += 1
            print("stride_number:", stride_number)
            if stride_number == 2:
                im1 = image[i[1]-25+stride_number*shift:i[1]+25+stride_number*shift, i[0]-25+stride_number*shift:i[0]+ 25 + stride_number*shift] #stride_right 2
                mini_image.append(im1)
                stride_number += 1
            print("stride_number:", stride_number)
            if stride_number == 3:
                im1 = image[i[1]-25+stride_number*shift:i[1]+25+stride_number*shift, i[0]-25+stride_number*shift:i[0]+ 25 + stride_number*shift] #stride_right 1
                mini_image.append(im1)
                stride_number += 1
                pass
        stride_right()
        #stride_left()
        #stride_up()
        #stride_down()
        
crop()            
#print(len(mini_image))
for k in range(len(mini_image)):
    pass
    #print("K:",k)
'''

# %%
# Opens a image in RGB mode 
#im = Image.open(r"/Users/keshavaprasad/Desktop/image_20/S25_00.tif")

# Size of the image in pixels (size of orginal image) 
#width, height = im.size 
#print(width)
#print(height)
# Setting the points for rectangle of cropped image 
        #left = i-50
        #top = i+50
        #right = j+50
        #bottom = j+50
# Cropped image of above dimension 
            # (It will not change orginal image) 
            #im1 = im.crop((left, top, right, bottom))
            #mini_image.append(im1)
            #cv2.imshow("mini_image", mini_image)
            #print("Number of Mini images:",len(mini_image))
