# %% [markdown]
# <a href="https://colab.research.google.com/github/keshavprasadgubbi/RabiesDetection/blob/master/Binary_Classification_ModelB-colabversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from keras.optimizers import Adam
#from Data_Preparation_1 import *
from keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import random

# %%
from google.colab import drive
from pathlib import Path
import sys
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
base = Path('/content/drive/My Drive/RabiesNeuronClassifier/')
sys.path.append(str(base))

# %%
# %cd /content/drive/My\ Drive/RabiesNeuronClassifier/
# Out:
# /content/drive/My Drive/RabiesNeuronClassifier

# %%
# !ls
# Out:
# 150epoch_trial5data		    data_preparation_1.py   trial10
# 200epoch_trial5data		    Estimates.ipynb	    trial5
# Binary_Classification_ModelB.ipynb  FP_FN_Estimation.ipynb  trial5.zip
# Binary-Inference.ipynb		    NewLandmarks.ipynb
# Data_Preparation_1.ipynb	    trial

# %%
#zip_path = 'trial5.zip'
#!cp “{zip_path}” .
# Out:
# cp: cannot stat '“trial5.zip”': No such file or directory

# %%
# !unzip trial5.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: trial5/Neuron/S20_right_284.tif
#   inflating: trial5/Neuron/S20_right_285.tif
#   inflating: trial5/Neuron/S20_right_288.tif
#   inflating: trial5/Neuron/S20_right_29.tif
#   inflating: trial5/Neuron/S20_right_292.tif
#   inflating: trial5/Neuron/S20_right_293.tif
#   inflating: trial5/Neuron/S20_right_296.tif
#   inflating: trial5/Neuron/S20_right_297.tif
#   inflating: trial5/Neuron/S20_right_30.tif
#   inflating: trial5/Neuron/S20_right_300.tif
#   inflating: trial5/Neuron/S20_right_301.tif
#   inflating: trial5/Neuron/S20_right_304.tif
#   inflating: trial5/Neuron/S20_right_305.tif
#   inflating: trial5/Neuron/S20_right_308.tif
#   inflating: trial5/Neuron/S20_right_309.tif
#   inflating: trial5/Neuron/S20_right_312.tif
#   inflating: trial5/Neuron/S20_right_317.tif
#   inflating: trial5/Neuron/S20_right_318.tif
#   inflating: trial5/Neuron/S20_right_32.tif
#   inflating: trial5/Neuron/S20_right_320.tif
#   inflating: trial5/Neuron/S20_right_324.tif
#   inflating: trial5/Neuron/S20_right_328.tif
#   inflating: trial5/Neuron/S20_right_33.tif
#   inflating: trial5/Neuron/S20_right_332.tif
#   inflating: trial5/Neuron/S20_right_333.tif
#   inflating: trial5/Neuron/S20_right_336.tif
#   inflating: trial5/Neuron/S20_right_337.tif
#   inflating: trial5/Neuron/S20_right_344.tif
#   inflating: trial5/Neuron/S20_right_345.tif
#   inflating: trial5/Neuron/S20_right_348.tif
#   inflating: trial5/Neuron/S20_right_349.tif
#   inflating: trial5/Neuron/S20_right_352.tif
#   inflating: trial5/Neuron/S20_right_353.tif
#   inflating: trial5/Neuron/S20_right_356.tif
#   inflating: trial5/Neuron/S20_right_36.tif
#   inflating: trial5/Neuron/S20_right_360.tif
#   inflating: trial5/Neuron/S20_right_361.tif
#   inflating: trial5/Neuron/S20_right_364.tif
#   inflating: trial5/Neuron/S20_right_368.tif
#   inflating: trial5/Neuron/S20_right_37.tif
#   inflating: trial5/Neuron/S20_right_372.tif
#   inflating: trial5/S55_right_694.tif
#   inflating: trial5/S55_right_695.tif
#   inflating: trial5/S55_right_696.tif
#   inflating: trial5/S55_right_697.tif
#   inflating: trial5/S55_right_698.tif
#   inflating: trial5/S55_right_699.tif
#   inflating: trial5/S55_right_7.tif
#   inflating: trial5/S55_right_70.tif
#   inflating: trial5/S55_right_700.tif
#   inflating: trial5/S55_right_701.tif
#   inflating: trial5/S55_right_702.tif
#   inflating: trial5/S55_right_703.tif
#   inflating: trial5/S55_right_706.tif
#   inflating: trial5/S55_right_707.tif
#   inflating: trial5/S55_right_71.tif
#   inflating: trial5/S55_right_710.tif
#   inflating: trial5/S55_right_711.tif
#   inflating: trial5/S55_right_712.tif
#   inflating: trial5/S55_right_713.tif
#   inflating: trial5/S55_right_714.tif
#   inflating: trial5/S55_right_715.tif
#   inflating: trial5/S55_right_717.tif
#   inflating: trial5/S55_right_718.tif
#   inflating: trial5/S55_right_719.tif
#   inflating: trial5/S55_right_721.tif
#   inflating: trial5/S55_right_722.tif
#   inflating: trial5/S55_right_723.tif
#   inflating: trial5/S55_right_725.tif
#   inflating: trial5/S55_right_726.tif
#   inflating: trial5/S55_right_727.tif
#   inflating: trial5/S55_right_729.tif
#   inflating: trial5/S55_right_730.tif
#   inflating: trial5/S55_right_731.tif
#   inflating: trial5/S55_right_74.tif
#   inflating: trial5/S55_right_75.tif
#   inflating: trial5/S55_right_78.tif
#   inflating: trial5/S55_right_79.tif
#   inflating: trial5/S55_right_82.tif
#   inflating: trial5/S55_right_83.tif
#   inflating: trial5/S55_right_87.tif
#   inflating: trial5/S55_right_89.tif
#   inflating: trial5/S55_right_90.tif
#   inflating: trial5/S55_right_91.tif
#   inflating: trial5/S55_right_98.tif
#   inflating: trial5/S55_right_99.tif

# %%
#DATADIR = '/content/drive/My Drive/RabiesNeuronClassifier/trial5/'
DATADIR = 'trial5/'
#CATEGORIES = ["Background","Single","Partial"]
#CATEGORIES = ["Background","GarbageForeground","Single","Partial"]
#CATEGORIES = ["Background","GarbageForeground","Single"]
CATEGORIES = ["Background","Neuron"]
def create_training_data():
    Training_Data = []
    img_size = 70
    X = []
    y = []
    for categories in CATEGORIES:
        Path = os.path.join(DATADIR,categories) # gives the path to the images; Data/Train/Image or Background
        print(Path)
        #print(len(os.listdir("//ibs9010/current_data/Data_Keshav/image/Classification_model/Data/Train/Background/")))
        #print(len(os.listdir("//ibs9010/current_data/Data_Keshav/Cropped_Images/trial/")))
        #print(len(os.listdir("//ibs9010/current_data/Data_Keshav/image/Classification_model/Data/Train/Neuron/")))
        #print(len(os.listdir("//ibs9010/current_data/Data_Keshav/Cropped_Images/trial/")))
        class_num = CATEGORIES.index(categories) # numbers the classes
        print(class_num)
        try:
            for img in os.listdir(Path): #gives the images from the path
                img_array = cv2.imread(os.path.join(Path,img),cv2.IMREAD_GRAYSCALE) 
                Training_Data.append([img_array,class_num])
                #plt.imshow(img_array,cmap='gray')
                #plt.show()
                #break
        except Exception as e:
            pass
    random.shuffle(Training_Data) # do it before conversion to array as list is mutable
    
    for features,labels in Training_Data:
        X.append(features)
        y.append(labels)
    #try:
    X = np.array(X).reshape(-1,img_size,img_size,1) # converts it to arrays with shape (number of images,dim of image)
    y = np.array(y)
    X = X/255.0 # this is normalization of only the images
    #except Exception as e:
     #       pass
    #print(y[5])
    return X,y

X,y = create_training_data()
# Out:
# trial5/Background
# 0
# trial5/Neuron
# 1

# %%
#def binary_classification_model():
model = Sequential()

model.add(Conv2D(128,(3,3),padding = 'same',input_shape=(X.shape[1:]),kernel_initializer = 'he_normal'))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
#model.add(Dropout(0.4))

model.add(Conv2D(128,(3,3),padding = 'same',input_shape=(X.shape[1:]),kernel_initializer = 'he_normal'))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
#model.add(Dropout(0.3))

model.add(Conv2D(128,(3,3),padding = 'same',input_shape=(X.shape[1:]),kernel_initializer = 'he_normal'))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
#model.add(Dropout(0.3))

model.add(Conv2D(64,(3,3),padding = 'same',input_shape=(X.shape[1:]),kernel_initializer = 'he_normal'))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
#model.add(Dropout(0.3))

model.add(Conv2D(64,(3,3),padding = 'same',kernel_initializer = 'he_normal'))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
#model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(64))
model.add(Activation("relu")) # added a hidden layer

model.add(Dense(64))
model.add(Activation("relu")) # added a new hidden layer

model.add(Dense(64))
model.add(Activation("relu")) # added a new hidden layer

model.add(Dense(64))
model.add(Activation("relu")) # added a new hidden layer

model.add(Dense(2))
#model.add(Dense(4))
model.add(Activation('softmax')) # chaging from sigmoid to softmax to include more classes

########################
#class_weight = {0: 1., 1: 15.}
#class_weight = {0: 5, 1: 10., 2: 1., 3:5.}
########################

#filepath="weights.best.hdf5"
ada = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss ="categorical_crossentropy", optimizer = 'adam', metrics = ["accuracy"])
y_train=to_categorical(y, num_classes=2)

model.summary()
#lr_model_history=model.fit(X,y_train,batch_size=64,epochs= 10,validation_split=0.1,class_weight=class_weight)
lr_model_history=model.fit(X,y_train,batch_size=64,epochs= 20,validation_split=0.1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 70, 70, 128)       1280
# _________________________________________________________________
# activation_10 (Activation)   (None, 70, 70, 128)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 35, 35, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 35, 35, 128)       147584
# _________________________________________________________________
# activation_11 (Activation)   (None, 35, 35, 128)       0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 17, 17, 128)       147584
# _________________________________________________________________
# activation_12 (Activation)   (None, 17, 17, 128)       0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 64)          73792
# _________________________________________________________________
# activation_13 (Activation)   (None, 8, 8, 64)          0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# activation_14 (Activation)   (None, 4, 4, 64)          0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                16448
# _________________________________________________________________
# activation_15 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# activation_16 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# activation_17 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                4160
# _________________________________________________________________
# activation_18 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 130
# _________________________________________________________________
# activation_19 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 436,226
# Trainable params: 436,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 151/151 [==============================] - 11s 75ms/step - loss: 0.3477 - accuracy: 0.8538 - val_loss: 0.2265 - val_accuracy: 0.9185
# Epoch 2/20
# 151/151 [==============================] - 11s 72ms/step - loss: 0.2398 - accuracy: 0.9028 - val_loss: 0.2403 - val_accuracy: 0.9064
# Epoch 3/20
# 151/151 [==============================] - 11s 72ms/step - loss: 0.2173 - accuracy: 0.9121 - val_loss: 0.1941 - val_accuracy: 0.9185
# Epoch 4/20
# 151/151 [==============================] - 11s 72ms/step - loss: 0.2042 - accuracy: 0.9173 - val_loss: 0.1807 - val_accuracy: 0.9288
# Epoch 5/20
# 151/151 [==============================] - 11s 72ms/step - loss: 0.1903 - accuracy: 0.9222 - val_loss: 0.3467 - val_accuracy: 0.8539
# Epoch 6/20
# 151/151 [==============================] - 11s 72ms/step - loss: 0.1810 - accuracy: 0.9282 - val_loss: 0.1723 - val_accuracy: 0.9363
# Epoch 7/20
# 151/151 [==============================] - 11s 72ms/step - loss: 0.1629 - accuracy: 0.9347 - val_loss: 0.1759 - val_accuracy: 0.9260
# Epoch 8/20
# 151/151 [==============================] - 11s 72ms/step - loss: 0.1503 - accuracy: 0.9385 - val_loss: 0.1857 - val_accuracy: 0.9307
# Epoch 9/20
# 151/151 [==============================] - 11s 72ms/step - loss: 0.1443 - accuracy: 0.9435 - val_loss: 0.1524 - val_accuracy: 0.9354
# Epoch 10/20
#  36/151 [======>.......................] - ETA: 7s - loss: 0.1143 - accuracy: 0.9536

# %%
model.save('/content/drive/My Drive/RabiesNeuronClassifier/200epoch_trial5data/')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/RabiesNeuronClassifier/200epoch_trial5data/assets

# %%
fig, ax = plt.subplots(1, 1, figsize=(15,5))
ax.plot(np.sqrt(lr_model_history.history['loss']), 'r', label='training')
ax.plot(np.sqrt(lr_model_history.history['val_loss']), 'b' ,label='validation')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'Loss', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# Plot the accuracy
fig, ax = plt.subplots(1, 1, figsize=(15,5))
ax.plot(np.sqrt(lr_model_history.history['accuracy']), 'r', label='training')
ax.plot(np.sqrt(lr_model_history.history['val_accuracy']), 'b' ,label='validation')
ax.set_xlabel(r'Epoch', fontsize=20)
ax.set_ylabel(r'Accuracy', fontsize=20)
ax.legend()
ax.tick_params(labelsize=20)

# %% [markdown]
# ## Loading Model

# %%
from tensorflow import keras
model = keras.models.load_model('//ibs9010/current_data/Data_Keshav/image/Classification_model/NeuronClassifierModels/BinaryClassifier_200epoch_4hidden_doubledata/')

# %% [markdown]
# ## Running inference on all Tiles

# %%
import os
import cv2
import numpy as np
img_size = 70 # fix the size of the image
Path = "//ibs9010/current_data/Data_Keshav/Cropped_Images/S61/" 
#Path = "//ibs9010/current_data/Data_Keshav/image/Classification_model/Data/Test/"
#Path = '//ibs9010/current_data/Data_Keshav/image/Classification_model/testingcrop/S055/'
Testing_image = []# list of testing images
image_name = []# list of image names

for img in os.listdir(Path): #gives the images from the path
    img_array = cv2.imread(os.path.join(Path,img),cv2.IMREAD_GRAYSCALE) # read every image in gray scale from the given path
    Testing_image.append(img_array)
    image_name.append(img)
    
print("Number of test images:",len(Testing_image))
#Running Inference
Test_image = np.array(Testing_image).reshape(-1,img_size,img_size,1)
#make an array of every element of list from Testing_image and then reshape them
Test_image = Test_image/255.0
scores = model.predict_classes(Test_image)

# Results
neuron_image_counter = bkgd_image_counter = 0
for i in range(len(Test_image)):
    #print("Image:",image_name[i],"with score:",scores[i]) 
    if scores[i]==0:
        bkgd_image_counter +=1
    if scores[i]==1:
        neuron_image_counter += 1
    
print("Total testing images:",len(Testing_image))
print("bkgd_image_counter:",bkgd_image_counter,"neuron_image_counter:",neuron_image_counter)

# %% [markdown]
# ## Saving classified tiles into respective folders

# %%
# saving the single neuron tiles into a particular folder for now - as a adhoc fix!
import os
import cv2
dest_path = '//ibs9010/current_data/Data_Keshav/image/Classification_model/Inference/BinaryClasses/singleneurontiles'
#dest_path = "//ibs9010/current_data/Data_Keshav/image/Classification_model/Inference/BinaryClasses/NewTestsingleneurontiles"
directory = '//ibs9010/current_data/Data_Keshav/image/Classification_model/Data/Test/'

# Delete all exiting images
import glob
os.chdir(dest_path)
files=glob.glob('*.tif')
for filename in files:
    os.unlink(filename)
    
#need the images of class1 to be appended in a separate list
single_image_list  = [] # contains list of filenames of single neurons
#sn_images = [] # conatins tiles of single neurons #(actual images itself)
for k in range(1,len(Test_image)):
    if scores[k]==1:
        #print(Test_image[i])
        #print("Image ",image_name[k])
        #sn_images.append(Test_image[i])
        single_image_list.append(image_name[k])
        
print(len(single_image_list))  
#image_name[i]
for i in range(len(Test_image)):
    if scores[i]==1:
        #print("Image:",image_name[i])
        #print("TestImage:",Test_image[i])
        #cv2.imwrite(image_name[i], Test_image[i])
        cv2.imwrite(os.path.join(dest_path,image_name[i]), Test_image[i]*255)
        #pass

# %% [markdown]
# # Generating Pickle files for classified tiles
# ## To be used for generating landmarks

# %%
# Generating pickle file For Single neurons
import pickle
with open('//ibs9010/current_data/Data_Keshav/image/Classification_model/23july_binary_SN_MG48_3day_bs_S051.pkl', 'wb') as f:
    pickle.dump(single_image_list, f)

# %%
# saving the bkgd neuron tiles into a particular folder for now - as a adhoc fix!
import os
import cv2
#dest_path = '//ibs9010/current_data/Data_Keshav/image/Classification_model/Inference/BinaryClasses/NewTestbackgroundneurontiles'
dest_path = '//ibs9010/current_data/Data_Keshav/image/Classification_model/Inference/BinaryClasses/backgroundneurontiles'
directory = '//ibs9010/current_data/Data_Keshav/image/Classification_model/Data/Test/'

# Delete all exiting images
import glob
os.chdir(dest_path)
files=glob.glob('*.tif')
for filename in files:
    os.unlink(filename)

#need the images of class1 to be appended in a separate list
bkgd_image_list  = [] # contains list of filenames of single neurons
#sn_images = [] # conatins tiles of single neurons #(actual images itself)
for k in range(1,len(Test_image)):
    if scores[k]==0:
        #print(Test_image[i])
        #print("Image ",image_name[k])
        #sn_images.append(Test_image[i])
        bkgd_image_list.append(image_name[k])
        
print(len(bkgd_image_list))  
#image_name[i]
for i in range(len(Test_image)):
    if scores[i]==0:
        #print("Image:",image_name[i])
        #print("TestImage:",Test_image[i])
        #cv2.imwrite(image_name[i], Test_image[i])
        cv2.imwrite(os.path.join(dest_path,image_name[i]), Test_image[i]*255)
        #pass
